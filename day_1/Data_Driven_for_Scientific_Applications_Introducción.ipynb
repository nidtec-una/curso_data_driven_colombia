# %% [markdown]
# ![Colab logo](https://ciencias.cayetano.edu.pe/wp-content/uploads/sites/28/2024/04/ivencuentro-1024x375.jpg)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Data Driven for Scientific Applications (8 hs)**
#
# I. [Introducción a Data Driven (4 hs)](https://www.youtube.com/watch?v=XX-sGwC98KM)
#
# >  13 de Mayo del 2024 |
# 11:00-15:00 (Col-Per) |
# 13:00-17:00 (Par)
#
# II. [Aplicaciones 1: Casos de Estudio cientifico (2 hs)](https://www.youtube.com/watch?v=-nXhwOJT46E)
#
# >  14 de Mayo del 2024 |
# 12:00-14:00 (Col-Per) |
# 14:00-16:00 (Par)
#
# III. Aplicaciones 2: Casos de Estudio científico, caso práctico con programación (2 hs)
#
# > 15 de Mayo del 2024 |
# 12:00-14:00 (Col-Per) |
# 14:00-16:00 (Par)

# %% [markdown]
# ---
#
# > _`Dirigido a  estudiantes que estan iniciando su carrera universitaria y están interesados en tener una primera interacción con el uso de análisis de datos.`_
#
# ---

# %% [markdown]
# # **Introducción a Data Driven**

# %% [markdown]
# ## **Instructor**
#
# > Dr. Pastor E Pérez Estigarribia
#
#
# - [scholar.google](https://bit.ly/352EvtP)
#
# - [researchgate](https://bit.ly/3tJ6TLD)
#
# ---
# > `—> "Pastor is a biologist with a PhD in computer science and a doctoral
# thesis on theoretical mathematical models for epidemic control. During the COVID-19 pandemic, he has assisted the Paraguayan Ministry of Public Health with forecasts based on mathematical models. He has published articles on mathematical modelling for epidemic control, research on the use of models for forecasting and the development of computer systems for epidemiological surveillance. He has worked as an International Consultant, providing regional training on health emergency data analysis."`
#
# ---
#
# **Professional Experience**
#
# `—> 2022-current. Postgraduate Professor at the Polytechnic School, National University of Asunción (FPUNA). Professor in the Master and Specialization in Information and Communication Technologies. Professor in the master's and doctoral program in computer science. %>%	2023. Professor of the diploma course in Machine Learning. MITIC-FPUNA %>% 2023. Instructor in Macrotraining in Artificial Intelligence (MeIA) challenges. UNAM. Mexico  %>% 2023. Professor of the diploma course in Artificial Intelligence. MITIC-FPUNA  %>% 	2023. International PAHO Consultant, Health Emergencies Department (PHE) of the Pan American Health Organization (PAHO/WHO) %>%	2022. Professor in the diploma course "Introduction to Health Data Analysis". FPUNA %>%	2022. Coordinator and professor of the diploma course "Statistical Computing and Data Analysis". FPUNA %>%	2021-2022. Epidemiological data analyst. Ministry of Public Health and Social Welfare. Paraguay %>%	2020-2021. Assistance in the National PAHO, Paraguay, for the management and analysis of data from the emergence of the COVID-19 pandemic %>% 	2021. Development of a surveillance system for the identification of probable cases of COVID-19 (CONACYT: PINV20-129) %>%	2021. Simulation of epidemiological models for prediction and contingency of COVID-19 (CONACYT: PINV20-40)`

# %% [markdown]
# # [**Agenda de hoy**](https://colab.research.google.com/drive/12Dej0Q6M-XGM3VIFhuqTNFbnyqgXNlUV?usp=sharing)
#
# 1. [Data Driven](https://colab.research.google.com/drive/1VXo-8FxheqRjodT-bN_QJT6ldKydRlt6?usp=sharing)
#
#     1.1. ¿Qué es Data Driven?
#
#     1.2. Ventajas del Toma de Decisiones Basada en Datos (DDDM)
#
#     1.3. Proceso de DDDM
#
#     1.4. Review en data-driven science
#
# 2. [La Ciencia y Ciencia de Datos](https://colab.research.google.com/drive/1wQdq0qgMyEGNXZqQaWenv6X6wrA4kEfH?usp=sharing)
#
#     2.1. El método científico
#
#     2.2. Modelos para simular la realidad
#
#     2.3. La Ciencia y sus teorías de decisión ¿Cuál es el mejor modelo?
#
#     2.4. Agregar valor a los datos y grados de evidencia
#
# 3. [Ingeniería de datos (Teoría y Práctica)](https://colab.research.google.com/drive/1JCHoXNnb_v7vvBUi2m7c5fSbDYEEbeSE?usp=sharing)
#
#     3.1. Data Engineer
#
#     3.2. Arquitectura de canalización de datos
#
#     3.3. Formularios electrónicos
#
#     3.4. Extract, Transform, Load (ETL)
#
#     3.5. Clean & Tidy data
#
#     3.6. Ingeniería de atributos
#
# 4. [Analítica de datos (Teoría y Práctica)](https://colab.research.google.com/drive/1pdle5OrgiES8mkta_jJpPFzVvxoK2m-I?usp=sharing)
#
#     4.1. Analítica descriptiva (EDA)
#
#     4.2. Analítica de diagnóstico (Pruebas de hipótesis)
#
#     4.3. Analítica predicativa (Inferencia e IA)
#
#     4.4. Analítica prescriptiva
#
# 5. [Software para DDDM](https://colab.research.google.com/drive/1LayE9WUWA1vxS_v8Z3VQ1m9UR9zvUudB?usp=sharing) ([Dashboard](https://en.wikipedia.org/wiki/Dashboard_(computing) [web app](https://en.wikipedia.org/wiki/Web_application) Ejemplo en salud pública)
#
#     5.1. [EpyGraph](http://epygraph-demo.uaa.edu.py/es/)
#
#     5.3. [Riesgo de reborte](https://dgvs.mspbs.gov.py/riesgo-de-rebrote-covid-19/)
#
#     5.2. [EpyModel 1.0](http://epymodel.uaa.edu.py/)
#
#     5.2. [EpyModel 1.1](http://epymodel.uaa.edu.py:3000/)

# %% [markdown]
# ## **Recursos preliminares**

# %% [markdown]
# ![Colab logo](https://pbs.twimg.com/media/D6o6myMXsAEEmfh?format=jpg&name=medium)

# %% [markdown]
# ## [**Google Colab**](https://colab.research.google.com/?utm_source=scs-index)
#
# Google Colaboratory o simplemente colab es una plataforma en on-line gratuita que permite ejecutar cuadernos [Jupyter](https://jupyter.org/) y acceder a potentes recursos informáticos (_e.g._ T4 GPU, A100 GPU, V100 GPU, TPU)[$^{ver}$](https://en.wikipedia.org/wiki/Nvidia_Tesla). Colab está alojado en la infraestructura de la nube de Google, lo que significa que tiene acceso a potentes recursos informáticos sin necesidad de configurar ningún hardware o software en su máquina local. Si bien Colaboratory está dirigido principalmente a usuarios de [Python](https://www.python.org/about/), también es posible usar R con Colaboratory. En este cuaderno colab explicamos como usar R con Google Colab.
#
# Colab también viene con una serie de bibliotecas y paquetes preinstalados, lo que facilita comenzar con el análisis de datos, el [aprendizaje automático](https://saturncloud.io/glossary/machine-learning/) y otras tareas computacionales.

# %% [markdown]
# ## [**Python**](https://www.python.org/about/)
#
# Python es un lenguaje de programación de alto nivel ampliamente utilizado para la codificación con propósito general.
#
# Características clave:
#
# - Versatilidad: Python es versátil y fácil de usar, lo que permite a los desarrolladores trabajar rápidamente y crear soluciones efectivas.
#
# - Integración de sistemas: Python facilita la integración de sistemas y la automatización de tareas.
#
# - Amplia comunidad: Cuenta con una comunidad activa y una gran cantidad de bibliotecas y módulos disponibles.
#
# - Sintaxis legible: La sintaxis de Python es clara y legible, lo que facilita el aprendizaje y la colaboración en proyectos.
#
# - Multiparadigma: Python admite programación orientada a objetos, funcional e imperativa.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(150)
data = np.random.randn(3,50)
plt.scatter(x,data)

# %% [markdown]
# ## [**R**](https://www.r-project.org/)
#
# Antes de arrancar, veamos de que trata este Software. Si ya estas familiarizado con esta herramienta puedes pasar a la siguiente sección.
#
# > R es un entorno de software gratuito para gráficos y computación estadística. Es de uso frecuente en entornos académicos y científicos. Sin embargo, debido a una serie de características que destacamos a continuación, su popularidad se ha extendido a otras comunicades.
#
# Pensamos que la popularidad del software R ha aumentado por:
#
# - Contar con una amplia comunidad en computación estadística y ciencia de datos desarrollando nuevos paquetes. Esta característica lo hace un entorno dinámico y escalable.
#
# - Es gratuito y de Código abierto. Cualquier usuario puede acceder con mucha facilidad al Código fuente de las funciones.
#
# - Funciona como un lenguaje de alto nivel, lo cual hace que sea más fácil de aprender.
#
# - Su popularidad en entornos académicos y científicos apuntala una mayor confianza de las librerías disponibles.
#
# - Puede interconectarse con distintos sistemas. Compila y ejecuta en una amplia variedad de plataformas UNIX, Windows y MacOS.
#
# - No solo permite la implementación de flujos de trabajos. Además,  permite la automatización de reportes, desarrollo de tableros, entre otras tareas utiles para los analistas de datos.

# %% [markdown]
# # [**Configuración de R en Google Colaboratory**](https://saturncloud.io/blog/how-to-use-r-with-google-colaboratory/)
#
# En un entorno Colab puedes trabajar principalmente con Python por defecto. Sin embargo, también es posible utilizar R con Colab. Esto es lo que nos interesa. Para comenzar, deberá crear un nuevo cuaderno R en Colab.
#
# 1. Primero ten en cuenta que estas leyendo desde Google Colaboratory en tu navegador web estas indicaciones.
#
# 2. Haga clic en "Archivo" en la esquina superior izquierda, luego seleccione "Nuevo cuaderno".
#
# 3. En el menú desplegable, seleccione "R".
#
# Una vez que hayas creado este cuaderno, estas listo para empezar a trabajar y aprender sobre, deberá instalar los paquetes o bibliotecas adicionales que necesite usar en su código. Para hacer esto, puedes usar la función install.packages() en R.
#
# Por ejemplo, si desea instalar el paquete tidyverse, puede ejecutar el siguiente código:

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# Antes de arrancar con nuestras clases en colab, veamos algunas cuestiones básicas tales como:
#
# - Ejecución de código R en Google Colaboratory
#
#
# - Markdown en Google Colaboratory
#
# - Guardar y compartir su R Notebook en Google Colaboratory

# %% [markdown]
# ## **Código R en Google Colaboratory**
#
# Colab proporciona un entorno de codificación interactivo que le permite escribir y ejecutar código en celdas. Puedes incluir textos como los utilizados en este cuaderno utilizando entornos Markdown como se muestra en la siguiente sección.
#
# Para agregar una nueva celda tienes en la parte superior del cuaderno, o como mensaje emergente en la parte inferior de cada entorno las alternativas '+codigo' y '+texto' para introducir códigos o textos de forma respectiva.
#
# Para ejecutar una celda, puede hacer clic en el botón "Reproducir" al lado de la celda o usar el método abreviado de teclado "Shift+Enter".
#
# Por ejemplo, podría ejecutar el siguiente código para crear un diagrama de dispersión de las variables mpgy hpen el mtcarsconjunto de datos:

# %%
library(ggplot2)
ggplot(mtcars, aes(x=mpg, y=hp)) +
  geom_point() + theme_bw()
# Out:
# plot without title

# %% [markdown]
# [Ver: notebooks/snippets/r](https://colab.research.google.com/notebooks/snippets/r.ipynb)

# %% [markdown]
# # [**Markdown en Google Colaboratory**](https://colab.research.google.com/notebooks/markdown_guide.ipynb?hl=es)
#
# Una de las ventajas maravillosas de un entorno colab es lo interactivo que resulta para incluir textos enriquecidos. Es posible incluir hipervínculos, imágenes, videos, ecuaciones con latex y recursos de html.
#
# Algunos sitios útiles para aprender más sobre esto son:
#
# * [Github Markdown basics](https://help.github.com/articles/markdown-basics/)
# * [Github flavored Markdown](https://help.github.com/articles/github-flavored-markdown/)
# * [Original Markdown spec: Syntax](http://daringfireball.net/projects/markdown/syntax)
# * [Original Markdown spec: Basics](http://daringfireball.net/projects/markdown/basics)
# * [marked.js library used by Colab](https://github.com/chjj/marked)
# * [LaTex mathematics for equations](https://en.wikibooks.org/wiki/LaTeX/Mathematics)

# %% [markdown]
# # **Guardar y compartir una Notebook en Google Colaboratory**
#
# Luego de finalizar un análisis o proyecto en Colab, es probable que quiera guardar su cuaderno de R para poder acceder a él más tarde o compartirlo con otros colaboradores, ya sea de forma pública o privada.
#
# Para guardar su cuaderno R en Colab, puede hacer clic en "Archivo" en la esquina superior izquierda y seleccionar "Guardar" o usar el método abreviado de teclado "Ctrl+S". Colab guardará su computadora portátil en su cuenta de Google Drive, donde podrá acceder a ella más tarde.
#
# Haciendo clip en el botón compartir tiene un menú emergente similar a otras documentos o proyectos en la nube de google, allí puedes generar un enlace para compartirlo. también puedes compartir con colaboradores específicos por medio de un correo electrónico.
#
# Ahora estamos listos para practicar con nuestros códigos desde un navegador web, en un entorno [responsivo](https://es.wikipedia.org/wiki/Responsividad) y [adaptable](https://es.wikipedia.org/wiki/Dise%C3%B1o_web_adaptable), ya sea con una notebook, celular o Tablet.
